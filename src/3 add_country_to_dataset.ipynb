# %% [markdown]
# # Add new country column to articles database

# %%
import pandas as pd
from time import time

# %% [markdown]
# ### Read original database

# %%
df = pd.read_csv('slam_articles.csv')

# %% [markdown]
# ### Read location dictionaries

# %%
import json

with open('publishers_dict.json') as file:
    publishers_dict = json.loads(file.read())

with open('publisher_locations_dict.json') as file:
    publisher_locations_dict = json.loads(file.read())

with open('universities_dict.json') as file:
    universities_dict = json.loads(file.read())

print('publishers_dict:',len(publishers_dict))
print('publisher_locations_dict:',len(publisher_locations_dict))
print('universities_dict:',len(universities_dict))
# Out:
# publishers_dict: 1561
# publisher_locations_dict: 104
# universities_dict: 7680

# %% [markdown]
# ### Create new columns

# %%
df['pub_c'] = None
df['pub_loc_c'] = None
df['uni_c'] = None
df.head()
# Out:
#                                                title  \
# 0  D3VIL-SLAM: 3D Visual Inertial LiDAR SLAM for ...
# 1  Visual and lidar-based SLAM by variational bay...
# 2  A Comparison of Outdoor 3D Reconstruction betw...
# 3  Indoor mapping and positioning applications of...
# 4  SC-LiDAR-SLAM: A Front-end Agnostic Versatile ...
#
#                                DOI                                  publisher  \
# 0    10.1109/iv55152.2023.10186534                                       IEEE
# 1            10.32657/10356/139813           Nanyang Technological University
# 2  10.1109/cacs60074.2023.10325866                                       IEEE
# 3            10.51946/melid.927004  Turkiye lidar dergisi (Mersin University)
# 4  10.1109/iceic54506.2022.9748644                                       IEEE
#
#   publisher_location  year                 type                score  \
# 0                NaN  2023  proceedings-article  proceedings-article
# 1                NaN  2020         dissertation         dissertation
# 2                NaN  2023  proceedings-article  proceedings-article
# 3                NaN  2021      journal-article      journal-article
# 4                NaN  2022  proceedings-article  proceedings-article
#
#    reference-count  is-referenced-by-count  \
# 0             23.0                     0.0
# 1              0.0                     0.0
# 2             10.0                     0.0
# 3             29.0                     5.0
# 4             46.0                    10.0
#
#                                              authors  \
# 0                     Matteo Frosi, Matteo Matteucci
# 1                                    , Xiaoyue Jiang
# 2                       Yi-Tian Hong, Han-Pang Huang
# 3                                     Mustafa ZEYBEK
# 4  Giseop Kim, Seungsang Yun, Jeongyun Kim, Ayoun...
#
#                                publisher_affiliation pub_c pub_loc_c uni_c
# 0  Information and Bioengineering Politecnico di ...  None      None  None
# 1                                                NaN  None      None  None
# 2  National Taiwan University, Department of Mech...  None      None  None
# 3                                                NaN  None      None  None
# 4  KAIST, Dept. of Civil and Envtl. Eng., Daejeon...  None      None  None

# %% [markdown]
# ### Fill new column

# %%
# add publisher
for key, value in publishers_dict.items():
    df.loc[df['publisher'] == key, "pub_c"] = value

# add publisher location
for key, value in publisher_locations_dict.items():
    df.loc[df['publisher_location'] == key, "pub_loc_c"] = value

# add university
for key, value in universities_dict.items():
    df.loc[df['publisher_affiliation'] == key, "uni_c"] = value

# %%
df.head()
# Out:
#                                                title  \
# 0  D3VIL-SLAM: 3D Visual Inertial LiDAR SLAM for ...
# 1  Visual and lidar-based SLAM by variational bay...
# 2  A Comparison of Outdoor 3D Reconstruction betw...
# 3  Indoor mapping and positioning applications of...
# 4  SC-LiDAR-SLAM: A Front-end Agnostic Versatile ...
#
#                                DOI                                  publisher  \
# 0    10.1109/iv55152.2023.10186534                                       IEEE
# 1            10.32657/10356/139813           Nanyang Technological University
# 2  10.1109/cacs60074.2023.10325866                                       IEEE
# 3            10.51946/melid.927004  Turkiye lidar dergisi (Mersin University)
# 4  10.1109/iceic54506.2022.9748644                                       IEEE
#
#   publisher_location  year                 type                score  \
# 0                NaN  2023  proceedings-article  proceedings-article
# 1                NaN  2020         dissertation         dissertation
# 2                NaN  2023  proceedings-article  proceedings-article
# 3                NaN  2021      journal-article      journal-article
# 4                NaN  2022  proceedings-article  proceedings-article
#
#    reference-count  is-referenced-by-count  \
# 0             23.0                     0.0
# 1              0.0                     0.0
# 2             10.0                     0.0
# 3             29.0                     5.0
# 4             46.0                    10.0
#
#                                              authors  \
# 0                     Matteo Frosi, Matteo Matteucci
# 1                                    , Xiaoyue Jiang
# 2                       Yi-Tian Hong, Han-Pang Huang
# 3                                     Mustafa ZEYBEK
# 4  Giseop Kim, Seungsang Yun, Jeongyun Kim, Ayoun...
#
#                                publisher_affiliation pub_c pub_loc_c  \
# 0  Information and Bioengineering Politecnico di ...  None      None
# 1                                                NaN  None      None
# 2  National Taiwan University, Department of Mech...  None      None
# 3                                                NaN  None      None
# 4  KAIST, Dept. of Civil and Envtl. Eng., Daejeon...  None      None
#
#          uni_c
# 0        Italy
# 1         None
# 2        China
# 3         None
# 4  South Korea

# %% [markdown]
# ### Combine country columns with prioritization

# %%
# Create the 'country' column with prioritization
df['country'] = df.apply(lambda row: row['uni_c'] if pd.notna(row['uni_c']) 
                               else (row['pub_loc_c'] if pd.notna(row['pub_loc_c']) 
                               else row['pub_c']), axis=1)
df = df.drop(columns=['pub_c', 'pub_loc_c', 'uni_c'])

# %%
df.head()
# Out:
#                                                title  \
# 0  D3VIL-SLAM: 3D Visual Inertial LiDAR SLAM for ...
# 1  Visual and lidar-based SLAM by variational bay...
# 2  A Comparison of Outdoor 3D Reconstruction betw...
# 3  Indoor mapping and positioning applications of...
# 4  SC-LiDAR-SLAM: A Front-end Agnostic Versatile ...
#
#                                DOI                                  publisher  \
# 0    10.1109/iv55152.2023.10186534                                       IEEE
# 1            10.32657/10356/139813           Nanyang Technological University
# 2  10.1109/cacs60074.2023.10325866                                       IEEE
# 3            10.51946/melid.927004  Turkiye lidar dergisi (Mersin University)
# 4  10.1109/iceic54506.2022.9748644                                       IEEE
#
#   publisher_location  year                 type                score  \
# 0                NaN  2023  proceedings-article  proceedings-article
# 1                NaN  2020         dissertation         dissertation
# 2                NaN  2023  proceedings-article  proceedings-article
# 3                NaN  2021      journal-article      journal-article
# 4                NaN  2022  proceedings-article  proceedings-article
#
#    reference-count  is-referenced-by-count  \
# 0             23.0                     0.0
# 1              0.0                     0.0
# 2             10.0                     0.0
# 3             29.0                     5.0
# 4             46.0                    10.0
#
#                                              authors  \
# 0                     Matteo Frosi, Matteo Matteucci
# 1                                    , Xiaoyue Jiang
# 2                       Yi-Tian Hong, Han-Pang Huang
# 3                                     Mustafa ZEYBEK
# 4  Giseop Kim, Seungsang Yun, Jeongyun Kim, Ayoun...
#
#                                publisher_affiliation      country
# 0  Information and Bioengineering Politecnico di ...        Italy
# 1                                                NaN         None
# 2  National Taiwan University, Department of Mech...        China
# 3                                                NaN         None
# 4  KAIST, Dept. of Civil and Envtl. Eng., Daejeon...  South Korea

# %% [markdown]
# ### Save new database

# %%
# Save the DataFrame to a CSV file with proper handling of newline characters
df.to_csv('slam_articles_with_country.csv', index=False, encoding='utf-8', quoting=1)

# %% [markdown]
# ### Check how many articles have a country

# %%
df_filtered = df.dropna(subset=['country'])
N = len(df)
c_N = len(df_filtered)

print(f"{c_N}/{N} ({(100*c_N/N):.1f}%) articles with country")
# Out:
# 12221/46913 (26.1%) articles with country
